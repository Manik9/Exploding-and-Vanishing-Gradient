# %% [markdown]
# # Vanishing and Exploding Gradient in Deep Neural Nets

# %% [markdown]
# Hello Stardust!
# Today we'll see mathematical reason behind exploding and vanishing gradient problem but first let's understand the problem in a nutshell.

# %% [markdown]
# Usually, when we train a Deep model using through backprop using Gradient Descent, we calculate the gradient of the output w.r.t to weight matrices and then subtract it from respective weight matrices to make its(matrix's) values more accurate to give correct output.
#
# *But what if the gradient becomes negligible?*
#
# When the gradient becomes negligible, subtracting it from original matrix doesn't makes any sense and hence the model stops learning.
# This problem is called as Vanishing Gradient Problem.

# %% [markdown]
# ### Let's see an example of Vanishing gradient problem

# %% [markdown]
# #### MNIST with 1 hidden layer containing 30 neurons

# %%
from IPython.display import Image
Image(filename='lstm/1 hidden.png')

# %% [markdown]
# #### MNIST with 2 hidden layer

# %%
from IPython.display import Image
Image(filename='lstm/2 hidden layer.png')

# %% [markdown]
# #### MNIST with 3 hidden layer

# %%
from IPython.display import Image
Image(filename='lstm/3 hidden layer.png')

# %% [markdown]
# #### MNIST with 4 hidden layers

# %%
from IPython.display import Image
Image(filename='lstm/4 hidden layer.png')

# %% [markdown]
# #### MNIST with 5 hidden layers

# %%
from IPython.display import Image
Image(filename='lstm/5 hidden layer.png')

# %% [markdown]
# ### When does the gradient becomes negligible?

# %% [markdown]
# To calculate gradient w.r.t to weight matrices, we use algorithm called backpropagation which uses chain Rule to calculate gradients. But if the network is deep enough, the value of the gradient becomes very small and which on subtracting from original weight matrices doesn't cause any considerable change in the weight matrices and hence the network stops learning.

# %% [markdown]
# #### Consider the neural network

# %%
from IPython.display import Image
Image(filename='lstm/Image 3.png')

# %% [markdown]
# #### Computational Graph of neural network above

# %%
from IPython.display import Image
Image(filename='lstm/Group 39.png')

# %% [markdown]
# #### Backpropagation

# %% [markdown]
# to calculate the derivate of C(output)  w.r.t b1

# %%
from IPython.display import Image
Image(filename='lstm/Group 42.png')

# %%
from IPython.display import Image
Image(filename='lstm/Image 1.png')

# %%
from IPython.display import Image
Image(filename='lstm/Image 3.png')

# %%
from IPython.display import Image
Image(filename='lstm/eqn.png')
